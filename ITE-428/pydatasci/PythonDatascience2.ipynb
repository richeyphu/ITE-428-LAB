# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# แสดงผลโดยไม่ต้องใช้คำสั่ง .show
# %matplotlib inline
# รูปความละเอียดสูง
# %config inlinebackend.figure_format = 'retina'

from IPython.display import YouTubeVideo, IFrame

# %%
df = pd.read_csv('/content/drive/MyDrive/Works TNI/1 2564/ITE-428/PythonDataScienceDataSource/carData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f96f8db9b90>,
# ...
#       dtype=object)

# %%
df['cty'].hist()

# %%
df['cty'].hist(bins=20, color='pink')

# %%
df['cty'].plot.density()

# %%
df.groupby(['manufacturer'])['cty','hwy'].agg('mean').sort_values(by=['cty'],ascending=[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     cty        hwy
# manufacturer
# honda         24.444444  32.555556
# volkswagen    20.925926  29.222222
# subaru        19.285714  25.571429
# hyundai       18.642857  26.857143
# toyota        18.529412  24.911765
# nissan        18.076923  24.615385
# audi          17.611111  26.444444
# pontiac       17.000000  26.400000
# chevrolet     15.000000  21.894737
# ford          14.000000  19.360000
# jeep          13.500000  17.625000
# mercury       13.250000  18.000000
# dodge         13.135135  17.945946
# land rover    11.500000  16.500000
# lincoln       11.333333  17.000000

# %%
df.groupby(['manufacturer'])['cty','hwy'].agg('mean').plot(kind='bar',
                                                           color=['navy','pink'],
                                                           title='Compare AVG city/hwy',
                                                           figsize=(10,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
